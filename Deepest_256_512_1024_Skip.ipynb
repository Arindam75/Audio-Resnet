# %% [markdown]
# <a href="https://colab.research.google.com/github/Arindam75/Audio-Resnet/blob/main/Deepest_256_512_1024_Skip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import os
import datetime
import pandas as pd

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Add,Dense,Flatten,Dropout,Input,Activation,MaxPooling2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import optimizers
from tensorflow.keras.utils import plot_model
from tensorflow.keras import initializers
import pandas as pd
from tensorflow.keras.regularizers import l2

# %%
path='/content/drive/My Drive/Environmental'
path
# Out:
# '/content/drive/My Drive/Environmental'

# %%
data = np.load(path+'/Training Data1.npz')
X_train=data['name1']
y_train=data['name2']

data = np.load(path+'/Validation Data1.npz')
X_val=data['name1']
y_val=data['name2']

# %%
X_train=X_train.reshape(X_train.shape[0],X_train.shape[1],X_train.shape[2],1)
X_val=X_val.reshape(X_val.shape[0],X_val.shape[1],X_val.shape[2],1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (24212, 13, 9, 1)
# (24212, 10)
# (71, 13, 9, 1)
# (71, 10)

# %%
def generator(X,y,batch_size):
  while True:
    samples=X.shape[0]
    batches=samples//batch_size
    
    for batch in range(0,batches):
        start=batch*batch_size
        stop=batch*batch_size+batch_size
        yield X[start:stop],y[start:stop]
    yield X[stop:],y[stop:]

# %%
train_batch_size=32
val_batch_size=32
num_epochs=150

num_train_sequences=X_train.shape[0]
num_val_sequences=X_val.shape[0]

train_generator = generator(X_train, y_train,train_batch_size)
val_generator = generator(X_val, y_val, val_batch_size)

if (num_train_sequences%train_batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/train_batch_size)
else:
    steps_per_epoch = (num_train_sequences//train_batch_size) + 1

if (num_val_sequences%val_batch_size) == 0:
    validation_steps = int(num_val_sequences/val_batch_size)
else:
    validation_steps = (num_val_sequences//val_batch_size) + 1

# %%
my_input=X_train.shape[1:]
X_input = Input(my_input)

# 1st Stage
X = Conv2D(16, (3, 3), strides=(1, 1), name='Conv1', padding='same',kernel_initializer='glorot_normal',activation='relu')(X_input)
X = BatchNormalization(axis=3, name='BN_Conv1')(X)

# 2nd Stage
X = Conv2D(32, (3, 3), strides=(1, 1), name='Conv2', padding='same',kernel_initializer='glorot_normal',activation='relu')(X)
X = BatchNormalization(axis=3, name='BN_Conv2')(X)

# 3rd Stage
X = Conv2D(64, (3,3), strides=(1, 1), name='Conv3', padding='same',kernel_initializer='glorot_normal',activation='relu')(X)
X = BatchNormalization(axis=3, name='BN_Conv3')(X)

# 4th Stage
X = Conv2D(128, (3,3), strides=(1, 1), name='Conv4', padding='same',kernel_initializer='glorot_normal',activation='relu')(X)
X_skip=X
X_skip = Conv2D(1024,(1, 1), strides = (1,1), name='Identity',padding = 'same',kernel_initializer = 'glorot_normal')(X_skip)
X = BatchNormalization(axis=3, name='BN_Conv4')(X)

#X_skip = BatchNormalization(axis=3, name='BN_Skip')(X_skip)
X = Conv2D(256, (3,3), strides=(1, 1), name='Conv5', padding='same',kernel_initializer='glorot_normal',activation='relu')(X)
X = BatchNormalization(axis=3, name='BN_Conv5')(X)

X = Conv2D(512, (3,3), strides=(1, 1), name='Conv6', padding='same',kernel_initializer='glorot_normal',activation='relu')(X)
X = BatchNormalization(axis=3, name='BN_Conv6')(X)

# 5th Stage
X = Conv2D(1024, (3,3), strides=(1, 1), name='Conv7', padding='same',kernel_initializer='glorot_normal')(X)
X = BatchNormalization(axis=3, name='BN_Conv7')(X)
X = Add(name='Addition')([X, X_skip])
X = Activation('relu',name='Relu')(X)
X = MaxPooling2D()(X)

X=Dropout(0.5)(X)
X=Flatten()(X)

X=Dense(128,activation='relu',kernel_initializer='glorot_normal')(X)
X=Dense(64,activation='relu',kernel_initializer='glorot_normal')(X)
X=Dense(10,activation='relu',kernel_initializer='glorot_normal')(X)

model = Model(inputs = X_input, outputs = X, name='ResNet50')
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['acc'])

# %%
plot_model(model, show_shapes=True)

# %%
print(model.summary())
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 13, 9, 1)]   0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 13, 9, 16)    160         input_2[0][0]
# __________________________________________________________________________________________________
# BN_Conv1 (BatchNormalization)   (None, 13, 9, 16)    64          Conv1[0][0]
# __________________________________________________________________________________________________
# Conv2 (Conv2D)                  (None, 13, 9, 32)    4640        BN_Conv1[0][0]
# __________________________________________________________________________________________________
# BN_Conv2 (BatchNormalization)   (None, 13, 9, 32)    128         Conv2[0][0]
# __________________________________________________________________________________________________
# Conv3 (Conv2D)                  (None, 13, 9, 64)    18496       BN_Conv2[0][0]
# __________________________________________________________________________________________________
# BN_Conv3 (BatchNormalization)   (None, 13, 9, 64)    256         Conv3[0][0]
# __________________________________________________________________________________________________
# Conv4 (Conv2D)                  (None, 13, 9, 128)   73856       BN_Conv3[0][0]
# __________________________________________________________________________________________________
# BN_Conv4 (BatchNormalization)   (None, 13, 9, 128)   512         Conv4[0][0]
# __________________________________________________________________________________________________
# Conv5 (Conv2D)                  (None, 13, 9, 256)   295168      BN_Conv4[0][0]
# __________________________________________________________________________________________________
# BN_Conv5 (BatchNormalization)   (None, 13, 9, 256)   1024        Conv5[0][0]
# __________________________________________________________________________________________________
# Conv6 (Conv2D)                  (None, 13, 9, 512)   1180160     BN_Conv5[0][0]
# __________________________________________________________________________________________________
# BN_Conv6 (BatchNormalization)   (None, 13, 9, 512)   2048        Conv6[0][0]
# __________________________________________________________________________________________________
# Conv7 (Conv2D)                  (None, 13, 9, 1024)  4719616     BN_Conv6[0][0]
# __________________________________________________________________________________________________
# BN_Conv7 (BatchNormalization)   (None, 13, 9, 1024)  4096        Conv7[0][0]
# __________________________________________________________________________________________________
# Identity (Conv2D)               (None, 13, 9, 1024)  132096      Conv4[0][0]
# __________________________________________________________________________________________________
# Addition (Add)                  (None, 13, 9, 1024)  0           BN_Conv7[0][0]
#                                                                  Identity[0][0]
# __________________________________________________________________________________________________
# Relu (Activation)               (None, 13, 9, 1024)  0           Addition[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 6, 4, 1024)   0           Relu[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 6, 4, 1024)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 24576)        0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          3145856     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10)           650         dense_4[0][0]
# ==================================================================================================
# Total params: 9,587,082
# Trainable params: 9,583,018
# Non-trainable params: 4,064
# __________________________________________________________________________________________________
# None

# %%
curr_dt_time = datetime.datetime.now()
model_name =path+'/skip_256_512_1024_Nov_8'+'/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{val_loss:.5f}-{acc:.5f}-{val_acc:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, 
                             save_weights_only=False, mode='auto', period=1)

callbacks_list = [checkpoint]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
filepath
# Out:
# '/content/drive/My Drive/Environmental/skip_256_512_1024_Nov_8/model-{epoch:05d}-{loss:.5f}-{val_loss:.5f}-{acc:.5f}-{val_acc:.5f}.h5'

# %%
history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list,validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Epoch 1/150
#   1/757 [..............................] - ETA: 17s - loss: 8.2855 - acc: 0.1250WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0159s vs `on_train_batch_end` time: 0.0253s). Check your callbacks.
# 757/757 [==============================] - ETA: 0s - loss: 5.2252 - acc: 0.3403
# Epoch 00001: val_acc improved from -inf to 0.54930, saving model to /content/drive/My Drive/Environmental/skip_256_512_1024_Nov_8/model-00001-5.22522-4.59227-0.34033-0.54930.h5
# 757/757 [==============================] - 24s 32ms/step - loss: 5.2252 - acc: 0.3403 - val_loss: 4.5923 - val_acc: 0.5493
# Epoch 2/150
# 757/757 [==============================] - ETA: 0s - loss: 3.5395 - acc: 0.3690
# Epoch 00002: val_acc did not improve from 0.54930
# 757/757 [==============================] - 23s 31ms/step - loss: 3.5395 - acc: 0.3690 - val_loss: 12.8199 - val_acc: 0.1127
# Epoch 3/150
# 757/757 [==============================] - ETA: 0s - loss: 3.0204 - acc: 0.4725
# Epoch 00003: val_acc did not improve from 0.54930
# 757/757 [==============================] - 23s 30ms/step - loss: 3.0204 - acc: 0.4725 - val_loss: 3.1370 - val_acc: 0.4930
# Epoch 4/150
# 757/757 [==============================] - ETA: 0s - loss: 2.8511 - acc: 0.4986
# Epoch 00004: val_acc improved from 0.54930 to 0.59155, saving model to /content/drive/My Drive/Environmental/skip_256_512_1024_Nov_8/model-00004-2.85108-3.45930-0.49864-0.59155.h5
# 757/757 [==============================] - 23s 31ms/step - loss: 2.8511 - acc: 0.4986 - val_loss: 3.4593 - val_acc: 0.5915
# Epoch 5/150
# 757/757 [==============================] - ETA: 0s - loss: 3.0191 - acc: 0.4591
# Epoch 00005: val_acc did not improve from 0.59155
# 757/757 [==============================] - 23s 30ms/step - loss: 3.0191 - acc: 0.4591 - val_loss: 3.7346 - val_acc: 0.1549
# Epoch 6/150
# 757/757 [==============================] - ETA: 0s - loss: 2.9768 - acc: 0.4195
# Epoch 00006: val_acc did not improve from 0.59155
# 757/757 [==============================] - 23s 30ms/step - loss: 2.9768 - acc: 0.4195 - val_loss: 3.6032 - val_acc: 0.5070
# Epoch 7/150
# 757/757 [==============================] - ETA: 0s - loss: 2.9687 - acc: 0.4074
# Epoch 00007: val_acc did not improve from 0.59155
# 757/757 [==============================] - 23s 30ms/step - loss: 2.9687 - acc: 0.4074 - val_loss: 3.5063 - val_acc: 0.4366
# Epoch 8/150
# 757/757 [==============================] - ETA: 0s - loss: 1.9952 - acc: 0.4970
# Epoch 00008: val_acc did not improve from 0.59155
# 757/757 [==============================] - 23s 30ms/step - loss: 1.9952 - acc: 0.4970 - val_loss: 1.9782 - val_acc: 0.5634
# Epoch 9/150
# 757/757 [==============================] - ETA: 0s - loss: 1.3141 - acc: 0.6012
# Epoch 00009: val_acc improved from 0.59155 to 0.70423, saving model to /content/drive/My Drive/Environmental/skip_256_512_1024_Nov_8/model-00009-1.31406-2.13184-0.60123-0.70423.h5
# 757/757 [==============================] - 24s 32ms/step - loss: 1.3141 - acc: 0.6012 - val_loss: 2.1318 - val_acc: 0.7042
# Epoch 10/150
# 757/757 [==============================] - ETA: 0s - loss: 1.3141 - acc: 0.5740
# Epoch 00010: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 1
150
# 757/757 [==============================] - ETA: 0s - loss: 0.9988 - acc: 0.7191
# Epoch 00030: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 0.9988 - acc: 0.7191 - val_loss: 2.6996 - val_acc: 0.5634
# Epoch 31/150
# 757/757 [==============================] - ETA: 0s - loss: 1.0264 - acc: 0.7046
# Epoch 00031: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 1.0264 - acc: 0.7046 - val_loss: 2.1430 - val_acc: 0.6479
# Epoch 32/150
# 757/757 [==============================] - ETA: 0s - loss: 0.9761 - acc: 0.7241
# Epoch 00032: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 0.9761 - acc: 0.7241 - val_loss: 2.2222 - val_acc: 0.3662
# Epoch 33/150
# 757/757 [==============================] - ETA: 0s - loss: 0.9215 - acc: 0.7250
# Epoch 00033: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 0.9215 - acc: 0.7250 - val_loss: 2.6329 - val_acc: 0.7042
# Epoch 34/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8779 - acc: 0.7414
# Epoch 00034: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8779 - acc: 0.7414 - val_loss: 2.9526 - val_acc: 0.6761
# Epoch 35/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8810 - acc: 0.7334
# Epoch 00035: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8810 - acc: 0.7334 - val_loss: 2.8241 - val_acc: 0.6056
# Epoch 36/150
# 757/757 [==============================] - ETA: 0s - loss: 1.1668 - acc: 0.6774
# Epoch 00036: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 1.1668 - acc: 0.6774 - val_loss: 2.2891 - val_acc: 0.6479
# Epoch 37/150
# 757/757 [==============================] - ETA: 0s - loss: 1.4307 - acc: 0.4857
# Epoch 00037: val_acc did not improve from 0.70423
# 757/757 [==============================] - 23s 30ms/step - loss: 1.4307 - acc: 0.4857 - val_loss: 3.0434 - val_acc: 0.2676
# Epoch 38/150
# 757/757 [==============================] - ETA: 0s - loss: 1.1283 - acc: 0.6187
# Epoch 00038: val_acc improved from 0.70423 to 0.71831, saving model to /content/drive/My Drive/Environmental/skip_256_512_1024_Nov_8/model-00038-1.12829-2.40742-0.61874-0.71831.h5
# 757/757 [==============================] - 23s 31ms/step - loss: 1.1283 - acc: 0.6187 - val_loss: 2.4074 - val_acc: 0.7183
# Epoch 39/150
# 757/757 [==============================] - ETA: 0s - loss: 0.9783 - acc: 0.7196
# Epoch 00039: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.9783 - acc: 0.7196 - val_loss: 2.1958 - val_acc: 0.6197
# Epoch 40/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8785 - acc: 0.7429
# Epoch 00040: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8785 - acc: 0.7429 - val_loss: 2.3965 - val_acc: 0.6761
# Epoch 41/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7585 - acc: 0.7812
# Epoch 00041: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.7585 - acc: 0.7812 - val_loss: 3.8088 - val_acc: 0.4789
# Epoch 42/150
# 757/757 [==============================] - ETA: 0s - loss: 1.2530 - acc: 0.5988
# Epoch 00042: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 1.2530 - acc: 0.5988 - val_loss: 2.0253 - val_acc: 0.5634
# Epoch 43/150
# 757/757 [==============================] - ETA: 0s - loss: 0.9869 - acc: 0.7251
# Epoch 00043: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.9869 - acc: 0.7251 - val_loss: 2.4301 - val_acc: 0.6197
# Epoch 44/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8268 - acc: 0.7602
# Epoch 00044: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8268 - acc: 0.7602 - val_loss: 3.1524 - val_acc: 0.6761
# Epoch 45/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8654 - acc: 0.7470
# Epoch 00045: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8654 - acc: 0.7470 - val_loss: 2.6807 - val_acc: 0.6901
# Epoch 46/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8051 - acc: 0.7682
# Epoch 00046: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8051 - acc: 0.7682 - val_loss: 2.2098 - val_acc: 0.6761
# Epoch 47/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8290 - acc: 0.7705
# Epoch 00047: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8290 - acc: 0.7705 - val_loss: 2.3928 - val_acc: 0.5352
# Epoch 48/150
# 757/757 [==============================] - ETA: 0s - loss: 1.1100 - acc: 0.7012
# Epoch 00048: val_acc did not improve from 0.71831
# 757/757 [==============================] - 23s 30ms/step - loss: 1.1100 - acc: 0.7012 - val_loss: 3.2192 - val_acc: 0.2254
# Epoch 49/150
# 757/757 [==============================] - ETA: 0s - loss: 0.
150
# 757/757 [==============================] - ETA: 0s - loss: 0.6750 - acc: 0.7991
# Epoch 00071: val_acc improved from 0.71831 to 0.76056, saving model to /content/drive/My Drive/Environmental/skip_256_512_1024_Nov_8/model-00071-0.67502-2.98949-0.79915-0.76056.h5
# 757/757 [==============================] - 23s 31ms/step - loss: 0.6750 - acc: 0.7991 - val_loss: 2.9895 - val_acc: 0.7606
# Epoch 72/150
# 757/757 [==============================] - ETA: 0s - loss: 0.9971 - acc: 0.7217
# Epoch 00072: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.9971 - acc: 0.7217 - val_loss: 2.6925 - val_acc: 0.6620
# Epoch 73/150
# 757/757 [==============================] - ETA: 0s - loss: 0.6437 - acc: 0.8117
# Epoch 00073: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.6437 - acc: 0.8117 - val_loss: 3.9252 - val_acc: 0.6056
# Epoch 74/150
# 757/757 [==============================] - ETA: 0s - loss: 0.9755 - acc: 0.7036
# Epoch 00074: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.9755 - acc: 0.7036 - val_loss: 2.7162 - val_acc: 0.4366
# Epoch 75/150
# 757/757 [==============================] - ETA: 0s - loss: 1.0503 - acc: 0.6681
# Epoch 00075: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 1.0503 - acc: 0.6681 - val_loss: 2.7464 - val_acc: 0.6197
# Epoch 76/150
# 757/757 [==============================] - ETA: 0s - loss: 0.8945 - acc: 0.7360
# Epoch 00076: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.8945 - acc: 0.7360 - val_loss: 2.2687 - val_acc: 0.5634
# Epoch 77/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7723 - acc: 0.7723
# Epoch 00077: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.7723 - acc: 0.7723 - val_loss: 3.0544 - val_acc: 0.6620
# Epoch 78/150
# 757/757 [==============================] - ETA: 0s - loss: 0.6616 - acc: 0.7998
# Epoch 00078: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.6616 - acc: 0.7998 - val_loss: 3.3085 - val_acc: 0.7042
# Epoch 79/150
# 757/757 [==============================] - ETA: 0s - loss: 0.5900 - acc: 0.8266
# Epoch 00079: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.5900 - acc: 0.8266 - val_loss: 3.2880 - val_acc: 0.7042
# Epoch 80/150
# 757/757 [==============================] - ETA: 0s - loss: 0.5687 - acc: 0.8366
# Epoch 00080: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.5687 - acc: 0.8366 - val_loss: 3.2546 - val_acc: 0.6901
# Epoch 81/150
# 757/757 [==============================] - ETA: 0s - loss: 1.1121 - acc: 0.7578
# Epoch 00081: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 1.1121 - acc: 0.7578 - val_loss: 2.7606 - val_acc: 0.6197
# Epoch 82/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7470 - acc: 0.8032
# Epoch 00082: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.7470 - acc: 0.8032 - val_loss: 5.6782 - val_acc: 0.2676
# Epoch 83/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7965 - acc: 0.7728
# Epoch 00083: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.7965 - acc: 0.7728 - val_loss: 3.5660 - val_acc: 0.6620
# Epoch 84/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7421 - acc: 0.7742
# Epoch 00084: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.7421 - acc: 0.7742 - val_loss: 1.8415 - val_acc: 0.5352
# Epoch 85/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7176 - acc: 0.7787
# Epoch 00085: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.7176 - acc: 0.7787 - val_loss: 2.5887 - val_acc: 0.6761
# Epoch 86/150
# 757/757 [==============================] - ETA: 0s - loss: 0.6329 - acc: 0.8120
# Epoch 00086: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.6329 - acc: 0.8120 - val_loss: 3.3295 - val_acc: 0.7042
# Epoch 87/150
# 757/757 [==============================] - ETA: 0s - loss: 0.5625 - acc: 0.8335
# Epoch 00087: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.5625 - acc: 0.8335 - val_loss: 3.4637 - val_acc: 0.6479
# Epoch 88/150
# 757/757 [==============================] - ETA: 0s - loss: 0.6119 - acc: 0.8232
# Epoch 00088: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.6119 - acc: 0.8232 - val_loss: 3.6430 - val_acc: 0.5070
# Epoch 89/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7370 - acc: 0.7614
# Epoch 00089: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.7370 - acc: 0.7614 - val_loss: 3.1634 - val_acc: 0.6761
# Epoch 90/150
# 757/757 [==============================] - ETA: 0s - loss: 0.5432 - acc: 0.8372
# Epoch 00090: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.5432 - acc: 0.8372 - val_loss: 3.4717 - val_acc: 0.7042
# Epoch 91/150
# 757/757 [==============================] - ETA: 0s - loss: 0.7130 - acc: 0.7944
# Epoch 00091: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.
val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.4126 - acc: 0.8815 - val_loss: 3.0709 - val_acc: 0.5352
# Epoch 137/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3703 - acc: 0.8903
# Epoch 00137: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.3703 - acc: 0.8903 - val_loss: 3.7124 - val_acc: 0.6197
# Epoch 138/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3099 - acc: 0.9124
# Epoch 00138: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.3099 - acc: 0.9124 - val_loss: 4.0958 - val_acc: 0.5775
# Epoch 139/150
# 757/757 [==============================] - ETA: 0s - loss: 0.5647 - acc: 0.8752
# Epoch 00139: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.5647 - acc: 0.8752 - val_loss: 3.7610 - val_acc: 0.6620
# Epoch 140/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3260 - acc: 0.9071
# Epoch 00140: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.3260 - acc: 0.9071 - val_loss: 3.6960 - val_acc: 0.5915
# Epoch 141/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3064 - acc: 0.9133
# Epoch 00141: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.3064 - acc: 0.9133 - val_loss: 4.0713 - val_acc: 0.6620
# Epoch 142/150
# 757/757 [==============================] - ETA: 0s - loss: 0.4806 - acc: 0.8717
# Epoch 00142: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.4806 - acc: 0.8717 - val_loss: 3.7081 - val_acc: 0.3099
# Epoch 143/150
# 757/757 [==============================] - ETA: 0s - loss: 0.6294 - acc: 0.8219
# Epoch 00143: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.6294 - acc: 0.8219 - val_loss: 3.3786 - val_acc: 0.6338
# Epoch 144/150
# 757/757 [==============================] - ETA: 0s - loss: 0.4191 - acc: 0.8782
# Epoch 00144: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.4191 - acc: 0.8782 - val_loss: 3.7321 - val_acc: 0.6620
# Epoch 145/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3729 - acc: 0.8893
# Epoch 00145: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.3729 - acc: 0.8893 - val_loss: 3.7373 - val_acc: 0.6056
# Epoch 146/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3386 - acc: 0.9017
# Epoch 00146: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.3386 - acc: 0.9017 - val_loss: 3.8693 - val_acc: 0.6197
# Epoch 147/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3271 - acc: 0.9089
# Epoch 00147: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 30ms/step - loss: 0.3271 - acc: 0.9089 - val_loss: 4.2769 - val_acc: 0.6479
# Epoch 148/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3764 - acc: 0.8972
# Epoch 00148: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.3764 - acc: 0.8972 - val_loss: 3.5638 - val_acc: 0.6197
# Epoch 149/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3345 - acc: 0.9072
# Epoch 00149: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.3345 - acc: 0.9072 - val_loss: 4.1213 - val_acc: 0.6197
# Epoch 150/150
# 757/757 [==============================] - ETA: 0s - loss: 0.3140 - acc: 0.9088
# Epoch 00150: val_acc did not improve from 0.76056
# 757/757 [==============================] - 23s 31ms/step - loss: 0.3140 - acc: 0.9088 - val_loss: 3.8345 - val_acc: 0.6197

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

fig1, (ax1, ax2) = plt.subplots(1, 2)
fig1.set_figwidth(20)
fig1.set_figheight(5)

#fig1.suptitle('Model 3 Conv 3D Performance No Pre Processing')
ax1.plot(history.history['loss'],label='Training')
ax1.plot(history.history['val_loss'],label='Validation')
ax1.set_title('Loss')
#ax1.set_ylim(0, 3)
ax1.legend(loc="upper right")

ax2.plot(history.history['acc'],label='Training')
ax2.plot(history.history['val_acc'],label='Validation')
ax2.set_title('Accuracy')
ax2.set_ylim(0.0, 1)
ax2.legend(loc="lower right")

# %%
result_deepest_skip=pd.DataFrame(list(zip(history.history['acc'],history.history['val_acc'],
history.history['loss'],history.history['val_loss'])),columns =['Acc1', 'Val_Acc1','Loss1','Val_loss1'])

# %%
result_deepest_skip.to_csv(path+'/skip_256_512_1024_Nov_8/result_deepest_skip.csv')
